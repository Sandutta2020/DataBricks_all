# %%
print("Hello Welcome to databricks")

# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %%
# %sql
Create table workspace.default.basic_table

# %%
# %sql
Create table if not exists main.default.project_credential
( owner_name STRING,
 object_name  STRING, 
 key_name STRING,
 value_data STRING,
 subject_name STRING) ;

delete from main.default.project_credential;

insert into main.default.project_credential (owner_name, object_name, key_name, value_data, subject_name)
values ('sandutta2020@gmail.com', 'null', 'username', 'sandutta2020@gmail.com','Data Ingestion');
insert into main.default.project_credential (owner_name, object_name, key_name, value_data, subject_name)
values ('sandutta2020@gmail.com', 'null', 'catalog_name', 'dbx_catalog','Data Ingestion');
insert into main.default.project_credential (owner_name, object_name, key_name, value_data, subject_name)
values ('sandutta2020@gmail.com', 'null', 'schema_name', 'dbx_schema','Data Ingestion');
insert into main.default.project_credential (owner_name, object_name, key_name, value_data, subject_name)
values ('sandutta2020@gmail.com', 'null', 'paths.working_dir', '/Volumes/dbx_catalog/dbx_schema/dbx_volume','Data Ingestion');
insert into main.default.project_credential (owner_name, object_name, key_name, value_data, subject_name)
values ('sandutta2020@gmail.com', 'null', 'warehouse_name', 'shared_warehouse','Data Ingestion');
insert into main.default.project_credential (owner_name, object_name, key_name, value_data, subject_name)
values ('sandutta2020@gmail.com', 'null', 'volume_name', 'dbx_volume','Data Ingestion');

# %%
spark.sql("Show catalogs like 'dbx_catalog'").count()

# %%
spark.sql("drop  catalog dbx_catalog cascade").count()

# %%
# %sql
SHOW CREATE TABLE dbx_catalog.dbx_schema.iris_table_demo;
